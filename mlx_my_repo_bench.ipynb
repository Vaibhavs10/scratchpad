# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavs10/scratchpad/blob/main/mlx_my_repo_bench.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q mlx-lm
# !pip install -q ipython-autotime
# %load_ext autotime
# Out:
# time: 338 µs (started: 2024-10-11 06:22:46 +00:00)

# %%
from mlx_lm import convert

repo = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
upload_repo = "reach-vb/test-mlx-repo-4-bit"

convert(repo, quantize=True, upload_repo=upload_repo)
# Out:
# [INFO] Loading
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# [INFO] Quantizing
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_experimental.py:58: UserWarning: 'plan_multi_commits' is experimental and might be subject to breaking changes in the future. You can disable this warning by setting `HF_HUB_DISABLE_EXPERIMENTAL_WARNING=1` as environment variable.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_experimental.py:58: UserWarning: 'HfApi.create_commits_on_pr' is experimental and might be subject to breaking changes in the future. You can disable this warning by setting `HF_HUB_DISABLE_EXPERIMENTAL_WARNING=1` as environment variable.
#   warnings.warn(
# Will create 0 deletion commit(s) and 1 addition commit(s), totalling 8 atomic operations.
# INFO:huggingface_hub.hf_api.create_commits_on_pr:Will create 0 deletion commit(s) and 1 addition commit(s), totalling 8 atomic operations.
# ...

# %%
import shutil
shutil.rmtree("mlx_model", ignore_errors=True)
# Out:
# time: 115 ms (started: 2024-10-11 06:42:19 +00:00)
