# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavs10/scratchpad/blob/main/conformer_wav2vec2_repro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 49.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 45.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 24.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 106.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.8 MB/s eta 0:00:00
# ...

# %%
import torch
from datasets import load_dataset
from transformers import pipeline

# %%
ds = load_dataset("hf-internal-testing/librispeech_asr_dummy", "clean", split="validation")
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating validation split: 0 examples [00:00, ? examples/s]

# %%
ds[0]
# Out:
# {'file': '/root/.cache/huggingface/datasets/downloads/extracted/dfbece23564f422bc5794f3090902cd16d52d86767b746125ebc2ff3ea5f89ef/dev_clean/1272/128104/1272-128104-0000.flac',
#  'audio': {'path': '/root/.cache/huggingface/datasets/downloads/extracted/dfbece23564f422bc5794f3090902cd16d52d86767b746125ebc2ff3ea5f89ef/dev_clean/1272/128104/1272-128104-0000.flac',
#   'array': array([0.00238037, 0.0020752 , 0.00198364, ..., 0.00042725, 0.00057983,
#          0.0010376 ]),
#   'sampling_rate': 16000},
#  'text': 'MISTER QUILTER IS THE APOSTLE OF THE MIDDLE CLASSES AND WE ARE GLAD TO WELCOME HIS GOSPEL',
#  'speaker_id': 1272,
#  'chapter_id': 128104,
#  'id': '1272-128104-0000'}

# %%
pipe = pipeline(
    "automatic-speech-recognition",
    model="facebook/wav2vec2-conformer-rope-large-960h-ft",
    device="cuda:0",
    torch_dtype=torch.float16,
)

# %%
pipe({"raw": ds[0]["audio"]["array"], "sampling_rate": ds[0]["audio"]["sampling_rate"]})
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-169552ee6f03> in <cell line: 1>()
# ----> 1 pipe({"raw": ds[0]["audio"]["array"], "sampling_rate": ds[0]["audio"]["sampling_rate"]})
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/automatic_speech_recognition.py in __call__(self, inputs, **kwargs)
#     354                     `"".join(chunk["text"] for chunk in output["chunks"])`.
#     355         """
# --> 356         return super().__call__(inputs, **kwargs)
#     357
#     358     def _sanitize_parameters(
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1119             return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1120         elif self.framework == "pt" and isinstance(self, ChunkPipeline):
# ...
