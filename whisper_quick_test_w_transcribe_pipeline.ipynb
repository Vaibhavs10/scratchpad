# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavs10/scratchpad/blob/main/whisper_quick_test_w_transcribe_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets transformers huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 57.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 20.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 21.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 61.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 30.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.9 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset
from transformers import pipeline
from huggingface_hub import notebook_login

# %%
notebook_login()

# %%
cv13 = load_dataset("mozilla-foundation/common_voice_13_0", "es", split="test", streaming=True)

# %%
next(iter(cv13))
# Out:
# Reading metadata...: 15708it [00:01, 13797.55it/s]
# {'client_id': '0003b969350f5308dc7347c574bc291834f38fdd92a2863b6059349b4be9738133855f3c49c0a6f7b7b01aff4be4573a1b066fbc7e1c26b1b9383c9d787acc5d',
#  'path': 'common_voice_es_19698530.mp3',
#  'audio': {'path': 'common_voice_es_19698530.mp3',
#   'array': array([ 0.00000000e+00, -8.56877286e-13,  6.45587316e-13, ...,
#           2.21531096e-04,  1.21658246e-04, -7.30805477e-05]),
#   'sampling_rate': 48000},
#  'sentence': 'Habita en aguas poco profundas y rocosas.',
#  'up_votes': 2,
#  'down_votes': 1,
#  'age': 'thirties',
#  'gender': 'male',
#  'accent': 'México',
#  'locale': 'es',
#  'segment': '',
#  'variant': ''}

# %%
pipe = pipeline("automatic-speech-recognition", model="openai/whisper-base", generate_kwargs={"task": "transcribe"})

# %%
pipe({"raw": next(iter(cv13))["audio"]["array"], "sampling_rate": next(iter(cv13))["audio"]["sampling_rate"]})
# Out:
# Reading metadata...: 15708it [00:00, 15933.36it/s]
# Reading metadata...: 15708it [00:00, 45693.56it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1346: UserWarning: Using `max_length`'s default (448) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# {'text': ' Abrientan aguas poco profundas y loco.'}
