# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavs10/scratchpad/blob/main/test_opt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("facebook/opt-125m")
model = AutoModelForCausalLM.from_pretrained("facebook/opt-125m")
# Out:
# tokenizer_config.json:   0%|          | 0.00/685 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/651 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/441 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/251M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/251M [00:00<?, ?B/s]

# %%
model.generate(**tokenizer("Hello, my dog is ", return_tensors="pt"))
# Out:
# tensor([[    2, 31414,     6,   127,  2335,    16,  1437, 48256,   102, 48256,
#             10,  2335,     4,  1437,  1437,  1437,  1437,  1437,  1437,  1437,
#           1437,  1437,  1437,  1437,  1437,  1437,  1437]])
