# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavs10/scratchpad/blob/main/seamless_recognition_repro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade git+https://github.com/huggingface/transformers.git sentencepiece
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-waa9vrcl
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-waa9vrcl
#   Resolved https://github.com/huggingface/transformers.git to commit facc66457ef79879cf63e5c02d6989ce98ac023d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.0 MB/s eta 0:00:00
# ...
#   Created wheel for transformers: filename=transformers-4.36.0.dev0-py3-none-any.whl size=8120560 sha256=607d7a6aa8891c4d0b741ad79ad4874cb3db1cf9a1614bed03a21ae745f857d6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-11ww4fyk/wheels/e7/9c/5b/e1a9c8007c343041e61cc484433d512ea9274272e3fcbe7c16
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
# ...

# %%
from transformers import pipeline

# %%
import torch

pipe = pipeline("automatic-speech-recognition",
                "facebook/seamless-m4t-v2-large",
                torch_dtype=torch.float16,
                device="cuda")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/9.91M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/19.7k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.17M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.34k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
pipe("https://huggingface.co/datasets/reach-vb/random-audios/resolve/main/4469669.mp3",)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-b02756950993> in <cell line: 1>()
# ----> 1 pipe("https://huggingface.co/datasets/reach-vb/random-audios/resolve/main/4469669.mp3",)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/automatic_speech_recognition.py in __call__(self, inputs, **kwargs)
#     355                     `"".join(chunk["text"] for chunk in output["chunks"])`.
#     356         """
# --> 357         return super().__call__(inputs, **kwargs)
#     358
#     359     def _sanitize_parameters(
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1132             return next(
#    1133                 iter(
# -> 1134                     self.get_iterator(
# ...
