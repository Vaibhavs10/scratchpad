# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavs10/scratchpad/blob/main/mms_asr_pipeline_error_repro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 86.6 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 36.6 MB/s eta 0:00:00
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 21.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 44.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 24.0 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 72.3 MB/s eta 0:00:00
# Collecting responses<0.19 (from datasets)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 13.2 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.9 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 15.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: tokenizers, xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface_hub, aiosignal, transformers, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.12.0 dill-0.3.6 frozenlist-1.3.3 huggingface_hub-0.15.1 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 tokenizers-0.13.3 transformers-4.29.2 xxhash-3.2.0 yarl-1.9.2

# %%
from transformers import pipeline
from datasets import load_dataset
from huggingface_hub import notebook_login

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
cv13 = load_dataset("mozilla-foundation/common_voice_13_0", "en", split="test", streaming=True)
# Out:
# Downloading builder script:   0%|          | 0.00/8.35k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/14.7k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.65k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/65.4k [00:00<?, ?B/s]

# %%
pipe = pipeline("automatic-speech-recognition", model="facebook/mms-1b-all")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/2.04k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/mms-1b-all were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.layers.35.adapter_layer.norm.bias', 'wav2vec2.encoder.layers.15.adapter_layer.linear_1.bias', 'wav2vec2.encoder.layers.31.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.11.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.8.adapter_layer.linear_1.weight', 'wav2vec2.encoder.layers.12.adapter_layer.linear_2.weight', 'wav2vec2.encoder.layers.10.adapter_layer.linear_2.bias', 'wav2vec2.encoder.layers.8.adapter_layer.norm.bias', 'wav2vec2.encoder.layers.44.adapter_layer.linear_1.bias', 'wav2vec2.encoder.layers.36.adapter_layer.linear_1.weight', 'wav2vec2.encoder.layers.14.adapter_layer.norm.bias', 'wav2vec2.encoder.layers.25.adapter_layer.linear_1.weight', 'wav2vec2.encoder.layers.22.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.5.adapter_layer.linear_2.weight', 'wav2vec2.encoder.layers.24.adapter_layer.linear_1.weight', 'wav2vec2.encoder.layers.25.adapter_layer.norm.bias', 'wav2vec2.encoder.layers.18.adapter_layer.norm.bias', 'wav2vec2.encoder.layers.27.adapter_layer.norm.bias', 'wav2vec2.encoder.layers.28.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.43.adapter_layer.linear_2.bias', 'wav2vec2.encoder.layers.23.adapter_layer.linear_2.weight', 'wav2vec2.encoder.layers.34.adapter_layer.linear_2.weight', 'wav2vec2.encoder.layers.29.adapter_layer.norm.bias', 'wav2vec2.encoder.layers.42.adapter_layer.linear_2.bias', 'wav2vec2.encoder.layers.31.adapter_layer.norm.bias', 'wav2vec2.encoder.layers.16.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.28.adapter_layer.norm.bias', 'wav2vec2.encoder.layers.32.adapter_layer.linear_2.weight', 'wav2vec2.encoder.layers.3.adapter_layer.linear_2.bias', 'wav2vec2.encoder.layers.34.adapter_layer.linear_1.bias', 'wav2vec2.encoder.layers.9.adapter_layer.linear_2.weight', 'wav2vec2.encoder.layers.24.adapter_layer.norm.bias', 'wav2vec2.encoder.layers.23.adapter_layer.linear_2.bias', 'wav2vec2.encoder.layers.44.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.3.adapter_layer.linear_2.weight', 'wav2vec2.encoder.layers.33.adapter_layer.norm.bias', 'wav2vec2.encoder.layers.32.adapter_layer.linear_2.bias', 'wav2vec2.encoder.layers.40.adapter_layer.linear_2.weight', 'wav2vec2.encoder.layers.30.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.37.adapter_layer.linear_2.bias', 'wav2vec2.encoder.layers.10.adapter_layer.linear_1.weight', 'wav2vec2.encoder.layers.5.adapter_layer.linear_1.weight', 'wav2vec2.encoder.layers.5.adapter_layer.norm.bias', 'wav2vec2.encoder.layers.37.adapter_layer.linear_1.bias', 'wav2vec2.encoder.layers.3.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.9.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.43.adapter_layer.linear_1.bias', 'wav2vec2.encoder.layers.35.adapter_layer.linear_1.weight', 'wav2vec2.encoder.layers.32.adapter_layer.linear_1.weight', 'wav2vec2.encoder.layers.2.adapter_layer.linear_1.weight', 'wav2vec2.encoder.layers.33.adapter_layer.linear_1.bias', 'wav2vec2.encoder.layers.29.adapter_layer.linear_2.weight', 'wav2vec2.encoder.layers.13.adapter_layer.linear_1.bias', 'wav2vec2.encoder.layers.36.adapter_layer.linear_2.bias', 'wav2vec2.encoder.layers.30.adapter_layer.linear_1.weight', 'wav2vec2.encoder.layers.7.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.23.adapter_layer.linear_1.weight', 'wav2vec2.encoder.layers.6.adapter_layer.linear_2.weight', 'wav2vec2.encoder.layers.47.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.22.adapter_layer.linear_2.bias', 'wav2vec2.encoder.layers.40.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.39.adapter_layer.linear_1.weight', 'wav2vec2.encoder.layers.45.adapter_layer.linear_1.bias', 'wav2vec2.encoder.layers.8.adapter_layer.linear_2.weight', 'wav2vec2.encoder.layers.13.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.1.adapter_layer.norm.weight', 'wav2vec2.encoder.layers.28.adapter_layer.linear_2.bias', 'wav2vec2.encoder.layers.16.adapter_layer.norm.bia ...
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading (…)okenizer_config.json:   0%|          | 0.00/397 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-3bddc6144bc6> in <cell line: 1>()
# ----> 1 pipe = pipeline("automatic-speech-recognition", model="facebook/mms-1b-all")
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     883                 tokenizer_kwargs.pop("torch_dtype", None)
#     884
# --> 885             tokenizer = AutoTokenizer.from_pretrained(
#     886                 tokenizer_identifier, use_fast=use_fast, _from_pipeline=task, **hub_kwargs, **tokenizer_kwargs
#     887             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     691                     f"Tokenizer class {tokenizer_class_candidate} does not exist or is not currently imported."
#     692                 )
# --> 693             return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     694
#     695         # Otherwise we have to be creative.
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, *init_inputs, **kwargs)
#    1810                 logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
#    1811
# -> 1812         return cls._from_pretrained(
#    1813             resolved_vocab_files,
#    1814             pretrained_model_name_or_path,
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in _from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, use_auth_token, cache_dir, local_files_only, _commit_hash, _is_local, *init_inputs, **kwargs)
#    1973         # Instantiate tokenizer.
#    1974         try:
# -> 1975             tokenizer = cls(*init_inputs, **init_kwargs)
#    1976         except OSError:
#    1977             raise OSError(
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/wav2vec2/tokenization_wav2vec2.py in __init__(self, vocab_file, bos_token, eos_token, unk_token, pad_token, word_delimiter_token, replace_word_delimiter_char, do_lower_case, **kwargs)
#     189         with open(vocab_file, encoding="utf-8") as vocab_handle:
#     190             self.encoder = json.load(vocab_handle)
# --> 191         self.decoder = {v: k for k, v in self.encoder.items()}
#     192
#     193         # make sure that tokens made of several
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/wav2vec2/tokenization_wav2vec2.py in <dictcomp>(.0)
#     189         with open(vocab_file, encoding="utf-8") as vocab_handle:
#     190             self.encoder = json.load(vocab_handle)
# --> 191         self.decoder = {v: k for k, v in self.encoder.items()}
#     192
#     193         # make sure that tokens made of several
#
# TypeError: unhashable type: 'dict'
