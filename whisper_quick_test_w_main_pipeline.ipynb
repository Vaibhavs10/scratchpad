# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavs10/scratchpad/blob/main/whisper_quick_test_w_main_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets git+https://github.com/huggingface/transformers.git huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-cba9jdxm
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-cba9jdxm
#   Resolved https://github.com/huggingface/transformers.git to commit f49a3453caa6fe606bb31c571423f72264152fce
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 28.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 24.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 15.5 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset
from transformers import pipeline
from huggingface_hub import notebook_login

# %%
notebook_login()

# %%
cv13 = load_dataset("mozilla-foundation/common_voice_13_0", "es", split="test", streaming=True)

# %%
next(iter(cv13))
# Out:
# Reading metadata...: 15708it [00:00, 32179.82it/s]
# {'client_id': '0003b969350f5308dc7347c574bc291834f38fdd92a2863b6059349b4be9738133855f3c49c0a6f7b7b01aff4be4573a1b066fbc7e1c26b1b9383c9d787acc5d',
#  'path': 'common_voice_es_19698530.mp3',
#  'audio': {'path': 'common_voice_es_19698530.mp3',
#   'array': array([ 0.00000000e+00, -8.56877286e-13,  6.45587316e-13, ...,
#           2.21531096e-04,  1.21658246e-04, -7.30805477e-05]),
#   'sampling_rate': 48000},
#  'sentence': 'Habita en aguas poco profundas y rocosas.',
#  'up_votes': 2,
#  'down_votes': 1,
#  'age': 'thirties',
#  'gender': 'male',
#  'accent': 'México',
#  'locale': 'es',
#  'segment': '',
#  'variant': ''}

# %%
pipe = pipeline("automatic-speech-recognition", model="openai/whisper-base")

# %%
pipe({"raw": next(iter(cv13))["audio"]["array"], "sampling_rate": next(iter(cv13))["audio"]["sampling_rate"]})
# Out:
# Reading metadata...: 15708it [00:00, 36049.59it/s]
# Reading metadata...: 15708it [00:00, 62527.35it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1349: UserWarning: Using `max_length`'s default (448) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# {'text': ' A bit of water, a little deep and crazy.'}

# %%
print(f'{pipe.model.config.forced_decoder_ids=}')
# Out:
# pipe.model.config.forced_decoder_ids=[[1, 50259], [2, 50359], [3, 50363]]
