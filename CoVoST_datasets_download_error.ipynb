# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavs10/scratchpad/blob/main/CoVoST_datasets_download_error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from datasets import load_dataset

ds = load_dataset("mozilla-foundation/common_voice_4_0", "en", use_auth_token=True)
# Out:
# ...
# WARNING:datasets.download.download_manager:Computing checksums of downloaded files. They can be used for integrity verification. You can disable this by passing ignore_verifications=True to load_dataset
# Computing checksums: 100%|##########| 1/1 [04:43<00:00, 283.64s/it]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating other split: 0 examples [00:00, ? examples/s]
# Generating invalidated split: 0 examples [00:00, ? examples/s]
# Dataset common_voice_4_0 downloaded and prepared to /root/.cache/huggingface/datasets/mozilla-foundation___common_voice_4_0/en/4.0.0/0fa8ed056598ca2c53155d6784867829fe112ffe40233423bbb85f398b5e2a1c. Subsequent calls will reuse this data.
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# !ls /root/.cache/huggingface/datasets/mozilla-foundation___common_voice_4_0/en/4.0.0/0fa8ed056598ca2c53155d6784867829fe112ffe40233423bbb85f398b5e2a1c
# Out:
# common_voice_4_0-invalidated.arrow  common_voice_4_0-train.arrow       LICENSE
# common_voice_4_0-other.arrow	    common_voice_4_0-validation.arrow
# common_voice_4_0-test.arrow	    dataset_info.json

# %%
from datasets import load_dataset

covost = load_dataset("covost2", "en_tr", data_dir="/root/.cache/huggingface/datasets/mozilla-foundation___common_voice_4_0/en/4.0.0/0fa8ed056598ca2c53155d6784867829fe112ffe40233423bbb85f398b5e2a1c", split="train")
# Out:
# WARNING:datasets.builder:Using custom data configuration en_tr-6d7e55e4cb3b94e3
# ...
# Generating train split:   0%|          | 0/289430 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/datasets/builder.py in _prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, split_info, check_duplicate_keys, job_id)
#    1570                 _time = time.time()
# -> 1571                 for key, record in generator:
#    1572                     if max_shard_size is not None and writer._num_bytes > max_shard_size:
#
# ~/.cache/huggingface/modules/datasets_modules/datasets/covost2/bba950aae1ffa5a14b876b7e09c17b44de2c3cf60e7bd5d459640beffc78e35b/covost2.py in _generate_examples(self, source_path, covost_tsv_path, cv_tsv_path, split)
#     158         covost_tsv = self._load_df_from_tsv(covost_tsv_path)
# ...
