# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavs10/scratchpad/blob/main/cv_datasets_bug_repro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q datasets huggingface_hub
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.8 MB/s eta 0:00:00

# %%
from datasets import load_dataset
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
cv = load_dataset("open-asr-leaderboard/datasets-test-only",
                  "common_voice",
                  "test",
                  streaming=True)
# Out:
# Downloading builder script:   0%|          | 0.00/56.4k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/12.4k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     260     try:
# --> 261         response.raise_for_status()
#     262     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/whoami-v2
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py in whoami(self, token)
#     933         try:
# --> 934             hf_raise_for_status(r)
#     935         except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     292             )
# --> 293             raise RepositoryNotFoundError(message, response) from e
#     294
#
# RepositoryNotFoundError: 401 Client Error. (Request ID: Root=1-64ede5c3-7bac5a0f6a9a73f025e4f0a3;dd95cf8e-f325-45cb-89c5-a91c49d5d67a)
#
# Repository Not Found for url: https://huggingface.co/api/whoami-v2.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated.
# Invalid username or password.
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-1c4d7e92af01> in <cell line: 1>()
# ----> 1 cv = load_dataset("open-asr-leaderboard/datasets-test-only",
#       2                   "common_voice",
#       3                   "test",
#       4                   streaming=True)
#
# /usr/local/lib/python3.10/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2127     # Return iterable dataset in case of streaming
#    2128     if streaming:
# -> 2129         return builder_instance.as_streaming_dataset(split=split)
#    2130
#    2131     # Some datasets are already processed on the HF google storage
#
# /usr/local/lib/python3.10/dist-packages/datasets/builder.py in as_streaming_dataset(self, split, base_path)
#    1327         )
#    1328         self._check_manual_download(dl_manager)
# -> 1329         splits_generators = {sg.name: sg for sg in self._split_generators(dl_manager)}
#    1330         # By default, return all splits
#    1331         if split is None:
#
# ~/.cache/huggingface/modules/datasets_modules/datasets/open-asr-leaderboard--datasets-test-only/bc4d578d078ecedf6a8b1fb60a582de80add3049b575ebf7ad05fe8f7b7c7e3f/datasets-test-only.py in _split_generators(self, dl_manager)
#     307             return self._librispeech_split_generators(dl_manager)
#     308         elif self.config.name == "common_voice":
# --> 309             return self._common_voice_split_generators(dl_manager)
#     310         elif self.config.name == "earnings22":
#     311             return self._earnings_split_generators(dl_manager)
#
# ~/.cache/huggingface/modules/datasets_modules/datasets/open-asr-leaderboard--datasets-test-only/bc4d578d078ecedf6a8b1fb60a582de80add3049b575ebf7ad05fe8f7b7c7e3f/datasets-test-only.py in _common_voice_split_generators(self, dl_manager)
#     608         dl_manager.download_config.ignore_url_params = True
#     609
# --> 610         self._common_voice_log_download("en", bundle_version, hf_auth_token)
#     611         archive_path = dl_manager.download(self._common_voice_get_bundle_url("en", _COMMON_VOICE_BUNDLE_URL_TEMPLATE))
#     612         local_extracted_archive = dl_manager.extract(archive_path) if not dl_manager.is_streaming else None
#
# ~/.cache/huggingface/modules/datasets_modules/datasets/open-asr-leaderboard--datasets-test-only/bc4d578d078ecedf6a8b1fb60a582de80add3049b575ebf7ad05fe8f7b7c7e3f/datasets-test-only.py in _common_voice_log_download(self, locale, bundle_version, auth_token)
#     592         if isinstance(auth_token, bool):
#     593             auth_token = HfFolder().get_token()
# --> 594         whoami = HfApi().whoami(auth_token)
#     595         email = whoami["email"] if "email" in whoami else ""
#     596         payload = {"email": email, "locale": locale, "dataset": bundle_version}
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     116             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     117
# --> 118         return fn(*args, **kwargs)
#     119
#     120     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py in whoami(self, token)
#     934             hf_raise_for_status(r)
#     935         except HTTPError as e:
# --> 936             raise HTTPError(
#     937                 "Invalid user token. If you didn't pass a user token, make sure you "
#     938                 "are properly logged in by executing `huggingface-cli login`, and "
#
# HTTPError: Invalid user token. If you didn't pass a user token, make sure you are properly logged in by executing `huggingface-cli login`, and if you did pass a user token, double-check it's correct.
