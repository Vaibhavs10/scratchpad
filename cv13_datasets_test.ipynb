# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavs10/scratchpad/blob/main/cv13_datasets_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 19.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 30.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 18.5 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import notebook_login
from datasets import load_dataset

# %%
notebook_login()

# %%
cv13 = load_dataset("mozilla-foundation/common_voice_13_0", "hi", split="test", streaming=True)

# %%
next(iter(cv13))
# Out:
# Reading metadata...: 2947it [00:00, 6910.01it/s]
# {'client_id': '00d8f7a5ea747472015787836b4694d24375a49cf2ca78088c1d29494110637aafa66bc0d135549c19cfc68886760475c2ae2584673c8d57e77eb82d3ddd6109',
#  'path': 'common_voice_hi_33797541.mp3',
#  'audio': {'path': 'common_voice_hi_33797541.mp3',
#   'array': array([ 8.67361738e-19, -2.38524478e-18, -9.43255890e-18, ...,
#          -8.23962182e-07, -5.09265362e-07, -1.74139529e-07]),
#   'sampling_rate': 48000},
#  'sentence': "मुरादनगर की 'मर्दानी' ने बदमाशों के छुड़ाए छक्के, भागने पर किया मजबूर",
#  'up_votes': 2,
#  'down_votes': 0,
#  'age': '',
#  'gender': '',
#  'accent': '',
#  'locale': 'hi',
#  'segment': '',
#  'variant': ''}

# %%
# !huggingface-cli logout
# Out:
# Successfully logged out.

# %%
cv13 = load_dataset("mozilla-foundation/common_voice_13_0", "hi", split="test", streaming=True)
# Out:
# WARNING:datasets.load:Using the latest cached version of the module from /root/.cache/huggingface/modules/datasets_modules/datasets/mozilla-foundation--common_voice_13_0/22809012aac1fc9803eaffc44122e4149043748e93933935d5ea19898587e4d7 (last modified on Wed Jun 14 10:13:17 2023) since it couldn't be found locally at mozilla-foundation/common_voice_13_0., or remotely on the Hugging Face Hub.
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/fsspec/implementations/http.py in _info(self, url, **kwargs)
#     416                 info.update(
# --> 417                     await _file_info(
#     418                         self.encode_url(url),
#
# /usr/local/lib/python3.10/dist-packages/fsspec/implementations/http.py in _file_info(url, session, size_policy, **kwargs)
#     836     async with r:
# --> 837         r.raise_for_status()
#     838
# ...
